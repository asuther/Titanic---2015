# %% [markdown]
# ## Building an Ensemble Predictor with RF and AdaBoost

# %%
import os
os.chdir('C:\Users\Lundi\Documents\Programming\Python\Kaggle\Titanic - 2015')

import TitanicPreprocessor as tp
import TitanicPredictor as tpred

import sklearn.ensemble as skl_ensemble
import sklearn.cross_validation as skl_cv
import sklearn.preprocessing as skl_pre
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

X, y, X_real_test, X_test_ids = tp.getData()

# %%
X_train, X_test, y_train, y_test = skl_cv.train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# ## Random Forest

# %%
rf_clf = skl_ensemble.RandomForestClassifier(
    max_features=4, 
    n_estimators=1000, 
    criterion ='entropy', 
    max_depth=5, 
    min_samples_leaf=2
)

# %%
y_pred_rf = skl_cv.cross_val_predict(rf_clf, X, y, cv=10)

# %% [markdown]
# ## AdaBoost
#
# #### Stump

# %%
dt_stump_clf = DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=1)
ada_dt_stump_clf = AdaBoostClassifier(
    base_estimator=dt_stump_clf,
    learning_rate=0.01,
    n_estimators=2883)

# %%
y_pred_ada_stump = skl_cv.cross_val_predict(ada_dt_stump_clf, X, y, cv=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-25fd6fee86b9> in <module>()
#       4     learning_rate=0.01,
#       5     n_estimators=2883)
# ----> 6 y_pred_ada_stump = skl_cv.cross_val_predict(ada_dt_stump_clf, X, y, cv=10)
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\cross_validation.pyc in cross_val_predict(estimator, X, y, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1255                                                       train, test, verbose,
#    1256                                                       fit_params)
# -> 1257                             for train, test in cv)
#    1258
#    1259     preds = [p for p, _ in preds_blocks]
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     802             self._iterating = True
#     803
# --> 804             while self.dispatch_one_batch(iterator):
#     805                 pass
#     806
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch_one_batch(self, iterator)
#     660                 return False
#     661             else:
# --> 662                 self._dispatch(tasks)
#     663                 return True
#     664
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in _dispatch(self, batch)
#     568
#     569         if self._pool is None:
# --> 570             job = ImmediateComputeBatch(batch)
#     571             self._jobs.append(job)
#     572             self.n_dispatched_batches += 1
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __init__(self, batch)
#     181         # Don't delay the application, to avoid keeping the input
#     182         # arguments in memory
# --> 183         self.results = batch()
#     184
#     185     def get(self):
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\cross_validation.pyc in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params)
#    1320         estimator.fit(X_train, **fit_params)
#    1321     else:
# -> 1322         estimator.fit(X_train, y_train, **fit_params)
#    1323     preds = estimator.predict(X_test)
#    1324     return preds, test
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\ensemble\weight_boosting.pyc in fit(self, X, y, sample_weight)
#     403
#     404         # Fit
# --> 405         return super(AdaBoostClassifier, self).fit(X, y, sample_weight)
#     406
#     407     def _validate_estimator(self):
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\ensemble\weight_boosting.pyc in fit(self, X, y, sample_weight)
#     138                 iboost,
#     139                 X, y,
# --> 140                 sample_weight)
#     141
#     142             # Early termination
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\ensemble\weight_boosting.pyc in _boost(self, iboost, X, y, sample_weight)
#     460         """
#     461         if self.algorithm == 'SAMME.R':
# --> 462             return self._boost_real(iboost, X, y, sample_weight)
#     463
#     464         else:  # elif self.algorithm == "SAMME":
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\ensemble\weight_boosting.pyc in _boost_real(self, iboost, X, y, sample_weight)
#     467     def _boost_real(self, iboost, X, y, sample_weight):
#     468         """Implement a single boost using the SAMME.R real algorithm."""
# --> 469         estimator = self._make_estimator()
#     470
#     471         try:
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\ensemble\base.pyc in _make_estimator(self, append)
#      74         sub-estimators.
#      75         """
# ---> 76         estimator = clone(self.base_estimator_)
#      77         estimator.set_params(**dict((p, getattr(self, p))
#      78                                     for p in self.estimator_params))
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\base.pyc in clone(estimator, safe)
#      47                             % (repr(estimator), type(estimator)))
#      48     klass = estimator.__class__
# ---> 49     new_object_params = estimator.get_params(deep=False)
#      50     for name, param in six.iteritems(new_object_params):
#      51         new_object_params[name] = clone(param, safe=False)
#
# C:\Users\Lundi\Miniconda2\lib\site-packages\sklearn\base.pyc in get_params(self, deep)
#     219             warnings.simplefilter("always", DeprecationWarning)
#     220             try:
# --> 221                 with warnings.catch_warnings(record=True) as w:
#     222                     value = getattr(self, key, None)
#     223                 if len(w) and w[0].category == DeprecationWarning:
#
# C:\Users\Lundi\Miniconda2\lib\warnings.pyc in __init__(self, record, module)
#     330         self._record = record
#     331         self._module = sys.modules['warnings'] if module is None else module
# --> 332         self._entered = False
#     333
#     334     def __repr__(self):
#
# KeyboardInterrupt:

# %% [markdown]
# #### Larger Tree

# %%
dt_clf = DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=1)
ada_dt_clf = AdaBoostClassifier(
    base_estimator=dt_clf,
    learning_rate=0.001,
    n_estimators=2766)

# %%
y_pred_ada_dt = skl_cv.cross_val_predict(ada_dt_clf, X, y, cv=10)

# %% [markdown]
# ## Combining Predictions

# %%
combined_predictions = pd.DataFrame([y_pred_rf, y_pred_ada_stump, y_pred_ada_dt]).T
combined_predictions.columns = ['random_forest', 'ada_stump','ada_dt']
combined_predictions
# Out:
#      random_forest  ada_stump  ada_dt
# 0                0          0       0
# 1                1          1       1
# 2                0          1       0
# 3                1          1       1
# 4                0          0       0
# 5                0          0       0
# 6                0          0       0
# 7                0          0       1
# 8                0          1       0
# 9                1          1       1
# 10               1          1       1
# 11               1          1       1
# 12               0          0       0
# 13               0          0       0
# 14               1          1       1
# 15               1          1       1
# 16               0          0       0
# 17               0          0       0
# 18               1          1       1
# 19               1          1       1
# 20               0          0       0
# 21               0          0       0
# 22               1          1       1
# 23               0          0       0
# 24               0          1       0
# 25               0          0       0
# 26               0          0       0
# 27               0          1       0
# 28               1          1       1
# 29               0          0       0
# ..             ...        ...     ...
# 861              0          0       0
# 862              1          1       1
# 863              0          0       0
# 864              0          0       0
# 865              1          1       1
# 866              1          1       1
# 867              0          0       0
# 868              0          0       0
# 869              1          0       1
# 870              0          0       0
# 871              1          1       1
# 872              0          0       0
# 873              0          0       0
# 874              1          1       1
# 875              1          1       1
# 876              0          0       0
# 877              0          0       0
# 878              0          0       0
# 879              1          1       1
# 880              1          1       1
# 881              0          0       0
# 882              1          1       0
# 883              0          0       0
# 884              0          0       0
# 885              0          0       0
# 886              0          0       0
# 887              1          1       1
# 888              0          1       0
# 889              0          0       0
# 890              0          0       0
#
# [891 rows x 3 columns]

# %%
combined_predictions.corr()
# Out:
#                random_forest  ada_stump    ada_dt
# random_forest       1.000000   0.830122  0.874387
# ada_stump           0.830122   1.000000  0.825108
# ada_dt              0.874387   0.825108  1.000000

# %% [markdown]
# These are heavily correlated. Most likely, the ensemble won't do significantly better

# %%
def getAccuracies(combined_y, y_actual):
    weighted_combined_y = combined_y.copy()
    weighted_combined_y['random_forest_2'] = weighted_combined_y['random_forest']
    weighted_combined_y['ada_dt_2'] = weighted_combined_y['ada_dt']
    combined_y['majority_vote'] = combined_y.apply(lambda row: row.value_counts().idxmax(), axis=1)
    return combined_y.apply(lambda col_predictions: np.mean(y_actual == col_predictions), axis=0)

# %%
getAccuracies(combined_predictions, y)
# Out:
# random_forest    0.833895
# ada_stump        0.808081
# ada_dt           0.823793
# majority_vote    0.831650
# dtype: float64

# %% [markdown]
# ## Predicting unknowns

# %%
ada_dt_clf.fit(X, y)
ada_dt_stump_clf.fit(X, y)
rf_clf.fit(X, y)

y_pred_ada_dt = ada_dt_clf.predict(X_real_test)
y_pred_ada_stump = ada_dt_stump_clf.predict(X_real_test)
y_pred_rf = rf_clf.predict(X_real_test)

combined_predictions = pd.DataFrame([y_pred_rf, y_pred_ada_stump, y_pred_ada_dt]).T
combined_predictions.columns = ['random_forest', 'ada_stump','ada_dt']

combined_predictions['majority_vote'] = combined_predictions.apply(lambda row: row.value_counts().idxmax(), axis=1)

# %%
y_pred_final = combined_predictions['majority_vote']

test_output = pd.DataFrame([X_test_ids, y_pred_final]).T
test_output.columns = ['PassengerId','Survived']
test_output.head()

test_output.to_csv('Data/test_output.csv', index=False)

# %% [markdown]
# Tied with top: Test Accuracy = 0.79426
